# %%
import sys
print(sys.executable)
# Out:
# /Users/adamaabanteriba/Desktop/Fun-fire-blight-detection/.venv/bin/python3

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# Processing parameters 
IMAGE_SIZE=256
BATCH_SIZE=32
SEED_NUM=78
TRAIN_SPLIT=0.2



# Go up one level (..), then into 00_data/raw
data_dir = '../00_data/raw'


tf.keras.preprocessing.image_dataset_from_directory?

# Use it with image_dataset_from_directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',  # Gets labels from folder names
    label_mode='categorical',  # or 'int' for integer labels
    batch_size=BATCH_SIZE,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    shuffle=True,
    seed=SEED_NUM,
    validation_split=TRAIN_SPLIT,
    subset='training'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    shuffle=True,
    seed=SEED_NUM,
    validation_split=TRAIN_SPLIT,
    subset='validation'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 16
#      13 get_ipython().run_line_magic('pinfo', 'tf.keras.preprocessing.image_dataset_from_directory')
#      15 # Use it with image_dataset_from_directory
# ---> 16 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#      17     data_dir,
#      18     labels='inferred',  # Gets labels from folder names
#      19     label_mode='categorical',  # or 'int' for integer labels
#      20     batch_size=BATCH_SIZE,
#      21     image_size=(IMAGE_SIZE, IMAGE_SIZE),
#      22     shuffle=True,
#      23     seed=SEED_NUM,
#      24     validation_split=TRAIN_SPLIT,
#      25     subset='training'
#      26 )
#      28 val_ds = tf.keras.preprocessing.image_dataset_from_directory(
#      29     data_dir,
#      30     labels='inferred',
#    (...)     37     subset='validation'
#      38 )
#
# File ~/Desktop/Fun-fire-blight-detection/.venv/lib/python3.11/site-packages/keras/src/utils/image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
#     271     seed=seed,
#     272     follow_links=follow_links,
#     273     verbose=verbose,
#     274 )
#     276 if label_mode == "binary" and len(class_names) != 2:
#     277     raise ValueError(
#     278         'When passing `label_mode="binary"`, there must be exactly 2 '
#     279         f"class_names. Received: class_names={class_names}"
#     280     )
#
# File ~/Desktop/Fun-fire-blight-detection/.venv/lib/python3.11/site-packages/keras/src/utils/dataset_utils.py:743, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     741 if labels == "inferred":
#     742     subdirs = []
# --> 743     for subdir in sorted(os_module.listdir(directory)):
#     744         if path_module.isdir(path_module.join(directory, subdir)):
#     745             if not subdir.startswith("."):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../00_data/raw'

# %%
# Add this cell first to see where you are
from pathlib import Path
import os

print(f"Current working directory: {os.getcwd()}")
print(f"Current directory (Path): {Path.cwd()}")

# List what's in current directory
print("\nFiles in current directory:")
for item in Path.cwd().iterdir():
    print(f"  {item.name}")
# Out:
# Current working directory: /Users/adamaabanteriba/Desktop/Fun-fire-blight-detection
# Current directory (Path): /Users/adamaabanteriba/Desktop/Fun-fire-blight-detection
#
# Files in current directory:
#   .DS_Store
#   LICENSE
#   00_data
#   requirements.txt
#   touch
#   Untitled.ipynb
#   .gitkeep
#   README.md
#   01_notebooks
#   .venv
#   scripts
#   .ipynb_checkpoints
#   .git
#   02_outputs
#   src
